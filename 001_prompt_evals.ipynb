# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",,
        "format": "python" or "json" or "regex",
        "solution_criteria": "Key criteria for evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()

# dataset

with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""

    prompt = f"""
    Please solve the following task:

    {test_case["task"]}

    * Respond only with Python, JSON, or a plain Regex
    * Do not add any comments or commentary or explanation
    """

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])

    return output

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    # TODO - Grading
    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean

def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean(result["score"] for result in results)
    print(f"Average Score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average Score: 6

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Bucket Name Parser\n\nHere's a solution to extract the bucket name from an S3 URI:\n\n```python\ndef parse_s3_bucket_name(s3_uri: str) -> str:\n    \"\"\"\n    Extract the bucket name from an S3 URI.\n    \n    Args:\n        s3_uri: S3 URI in the format 's3://bucket-name/path/to/object'\n        \n    Returns:\n        The bucket name\n        \n    Raises:\n        ValueError: If the URI is not a valid S3 URI\n    \"\"\"\n    if not s3_uri.startswith('s3://'):\n        raise ValueError(f\"Invalid S3 URI: {s3_uri}. Must start with 's3://'\")\n    \n    # Remove 's3://' prefix\n    uri_without_prefix = s3_uri[5:]\n    \n    # Extract bucket name (everything before the first '/')\n    bucket_name = uri_without_prefix.split('/')[0]\n    \n    if not bucket_name:\n        raise ValueError(f\"Invalid S3 URI: {s3_uri}. Bucket name is empty\")\n    \n    return bucket_name\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        ('s3://my-bucket-name/path/to/object.txt', 'my-bucket-name'),\n        ('s3://simple-bucket', 'simple-bucket'),\n        ('s3://bucket-with-many/nested/paths/file.json', 'bucket-with-many'),\n        ('s3://123-bucket/file', '123-bucket'),\n    ]\n    \n    for uri, expected in test_cases:\n        result = parse_s3_bucket_name(uri)\n        status = \"\u2713\" if result == expected else \"\u2717\"\n        print(f\"{status} Input: {uri}\")\n        print(f\"  Output: {result}\")\n        print(f\"  Expected: {expected}\\n\")\n```\n\n**Output:**\n```\n\u2713 Input: s3://my-bucket-name/path/to/object.txt\n  Output: my-bucket-name\n  Expected: my-bucket-name\n\n\u2713 Input: s3://simple-bucket\n  Output: simple-bucket\n  Expected: simple-bucket\n\n\u2713 Input: s3://bucket-with-many/nested/paths/file.json\n  Output: bucket-with-many\n  Expected: bucket-with-many\n\n\u2713 Input: s3://123-bucket/file\n  Output: 123-bucket\n  Expected: 123-bucket\n```\n\n## Alternative Solutions\n\n**Using regex (more robust):**\n```python\nimport re\n\ndef parse_s3_bucket_name_regex(s3_uri: str) -> str:\n    \"\"\"Extract bucket name using regex.\"\"\"\n    match = re.match(r's3://([a-zA-Z0-9._-]+)', s3_uri)\n    if not match:\n        raise ValueError(f\"Invalid S3 URI: {s3_uri}\")\n    return match.group(1)\n```\n\n**Using urllib (for URL parsing):**\n```python\nfrom urllib.parse import urlparse\n\ndef parse_s3_bucket_name_urllib(s3_uri: str) -> str:\n    \"\"\"Extract bucket name using urllib.\"\"\"\n    parsed = urlparse(s3_uri)\n    if parsed.scheme != 's3':\n        raise ValueError(f\"Invalid S3 URI: {s3_uri}\")\n    return parsed.netloc\n```\n\nThe first solution is simple and efficient for basic use cases, while the regex or urllib approaches provide more validation.",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from an S3 URI and extract just the bucket name. Example input: 's3://my-bucket-name/path/to/object.txt'",
#       "format": "regex",
#       "solution_criteria": "Must correctly extract 'my-bucket-name' from various S3 URI formats, handling both virtual-hosted and path-style URIs"
#     },
#     "score": 6,
#     "reasoning": "The solution correctly handles virtual-hosted style S3 URIs and the example provided, with clean code and good documentation. However, it falls short on the criteria requirement to handle both virtual-hosted AND path-style URI formats. Additionally, the lack of bucket name validation and the flawed regex alternative reduce robustness. For production AWS code, stricter validation against S3 naming conventions would be expected."
#   },
#   {
#     "output": "```python\nimport json\nfrom typing import List, Union\n\ndef extract_iam_policy_actions(policy_json: str) -> List[str]:\n    \"\"\"\n    Extract all actions from an AWS IAM policy JSON string.\n    \n    Args:\n        policy_json (str): A JSON string representing an AWS IAM policy\n        \n    Returns:\n        List[str]: A list of all actions specified in the policy\n        \n    Raises:\n        json.JSONDecodeError: If the input is not valid JSON\n        ValueError: If the policy structure is invalid\n        \n    Examples:\n        >>> policy = '''\n        ... {\n        ...     \"Version\": \"2012-10-17\",\n        ...     \"Statement\": [\n        ...         {\n        ...             \"Effect\": \"Allow\",\n        ...             \"Action\": \"s3:GetObject\",\n        ...             \"Resource\": \"*\"\n        ...         }\n        ...     ]\n        ... }\n        ... '''\n        >>> extract_iam_policy_actions(policy)\n        ['s3:GetObject']\n    \"\"\"\n    try:\n        policy = json.loads(policy_json)\n    except json.JSONDecodeError as e:\n        raise json.JSONDecodeError(f\"Invalid JSON policy: {e.msg}\", e.doc, e.pos)\n    \n    if not isinstance(policy, dict):\n        raise ValueError(\"Policy must be a JSON object (dictionary)\")\n    \n    actions = []\n    statements = policy.get(\"Statement\", [])\n    \n    if not isinstance(statements, list):\n        raise ValueError(\"'Statement' must be a list\")\n    \n    for statement in statements:\n        if not isinstance(statement, dict):\n            continue\n            \n        # Extract Action(s) from the statement\n        action_field = statement.get(\"Action\")\n        \n        if action_field is not None:\n            # Action can be a string or a list of strings\n            if isinstance(action_field, str):\n                actions.append(action_field)\n            elif isinstance(action_field, list):\n                actions.extend([a for a in action_field if isinstance(a, str)])\n    \n    return actions\n\n\n# Test cases\nif __name__ == \"__main__\":\n    # Test 1: Single action as string\n    policy1 = '''\n    {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": \"s3:GetObject\",\n                \"Resource\": \"arn:aws:s3:::my-bucket/*\"\n            }\n        ]\n    }\n    '''\n    print(\"Test 1 - Single action:\")\n    print(extract_iam_policy_actions(policy1))\n    print()\n    \n    # Test 2: Multiple actions as list\n    policy2 = '''\n    {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": [\n                    \"s3:GetObject\",\n                    \"s3:PutObject\",\n                    \"s3:DeleteObject\"\n                ],\n                \"Resource\": \"arn:aws:s3:::my-bucket/*\"\n            }\n        ]\n    }\n    '''\n    print(\"Test 2 - Multiple actions:\")\n    print(extract_iam_policy_actions(policy2))\n    print()\n    \n    # Test 3: Multiple statements with mixed action types\n    policy3 = '''\n    {\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": \"ec2:DescribeInstances\",\n                \"Resource\": \"*\"\n            },\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": [\n                    \"dynamodb:GetItem\",\n                    \"dynamodb:Query\"\n                ],\n                \"Resource\": \"arn:aws:dynamodb:*:*:table/MyTable\"\n            },\n            {\n                \"Effect\": \"Deny\",\n                \"Action\": \"iam:*\",\n                \"Resource\": \"*\"\n            }\n        ]\n    }\n    '''\n    print(\"Test 3 - Multiple statements",
#     "test_case": {
#       "task": "Create a Python function that takes an AWS IAM policy JSON string and returns a list of all actions (Resource-based or Identity-based) specified in the policy",
#       "format": "python",
#       "solution_criteria": "Function must parse JSON, handle nested statements, and return a deduplicated list of actions including wildcards like 's3:*'"
#     },
#     "score": 5,
#     "reasoning": "The solution successfully parses JSON and extracts actions from IAM policies with good error handling and code quality. However, it has a critical flaw: the criteria explicitly requires 'a deduplicated list of actions' but the implementation uses a plain list and extends it without deduplication. This means a policy with the same action in multiple statements would return duplicates. Additionally, AWS IAM policies can use 'NotAction' as an alternative to 'Action', which is not handled. The incomplete test output also suggests the solution may not have been fully tested."
#   },
#   {
#     "output": "# AWS Lambda Execution Role with S3 Read Permissions\n\nHere's a CloudFormation template snippet in JSON that creates a Lambda execution role with S3 read permissions:\n\n```json\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template for Lambda execution role with S3 read permissions\",\n  \"Resources\": {\n    \"LambdaExecutionRole\": {\n      \"Type\": \"AWS::IAM::Role\",\n      \"Properties\": {\n        \"RoleName\": \"LambdaS3ReadRole\",\n        \"AssumeRolePolicyDocument\": {\n          \"Version\": \"2012-10-17\",\n          \"Statement\": [\n            {\n              \"Effect\": \"Allow\",\n              \"Principal\": {\n                \"Service\": \"lambda.amazonaws.com\"\n              },\n              \"Action\": \"sts:AssumeRole\"\n            }\n          ]\n        },\n        \"ManagedPolicyArns\": [\n          \"arn:aws:iam::aws:policy/service-role/AWSLambdaBasicExecutionRole\"\n        ],\n        \"Policies\": [\n          {\n            \"PolicyName\": \"S3ReadPolicy\",\n            \"PolicyDocument\": {\n              \"Version\": \"2012-10-17\",\n              \"Statement\": [\n                {\n                  \"Effect\": \"Allow\",\n                  \"Action\": [\n                    \"s3:GetObject\",\n                    \"s3:ListBucket\"\n                  ],\n                  \"Resource\": [\n                    \"arn:aws:s3:::my-bucket\",\n                    \"arn:aws:s3:::my-bucket/*\"\n                  ]\n                }\n              ]\n            }\n          }\n        ]\n      }\n    }\n  },\n  \"Outputs\": {\n    \"LambdaExecutionRoleArn\": {\n      \"Description\": \"ARN of the Lambda execution role\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"LambdaExecutionRole\",\n          \"Arn\"\n        ]\n      }\n    }\n  }\n}\n```\n\n## Key Components:\n\n| Component | Description |\n|-----------|-------------|\n| **AssumeRolePolicyDocument** | Allows the Lambda service to assume this role |\n| **ManagedPolicyArns** | Attaches AWS managed policy for basic Lambda execution (CloudWatch Logs) |\n| **S3ReadPolicy** | Custom inline policy with S3 permissions |\n| **S3 Actions** | `s3:GetObject` (read objects) and `s3:ListBucket` (list bucket contents) |\n| **Resources** | Replace `my-bucket` with your actual S3 bucket name |\n\n## Usage Notes:\n\n- Replace `my-bucket` with your actual S3 bucket ARN/name\n- The `AWSLambdaBasicExecutionRole` managed policy enables CloudWatch Logs permissions\n- To restrict to specific buckets, update the `Resource` array accordingly",
#     "test_case": {
#       "task": "Generate a JSON CloudFormation template snippet that defines an AWS Lambda execution role with basic S3 read permissions",
#       "format": "json",
#       "solution_criteria": "Must include proper IAM role definition, assume role policy for Lambda service, and an inline policy granting s3:GetObject permissions"
#     },
#     "score": 7,
#     "reasoning": "The solution meets all core requirements: it defines a proper IAM role, includes a valid Lambda assume role policy, and grants s3:GetObject permissions via an inline policy. The structure is valid JSON and the permissions are correctly scoped. However, it has minor production-readiness issues around parameterization and the fixed RoleName that could cause deployment problems. The example is clear and well-documented but could be more enterprise-ready."
#   }
# ]
