# %%
# Install VoyageAI lib
# %pip install voyageai
# Out:
# Collecting voyageai
#   Downloading voyageai-0.2.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting aiohttp<4.0,>=3.5 (from voyageai)
#   Downloading aiohttp-3.13.5-cp314-cp314-win_amd64.whl.metadata (8.4 kB)
# Collecting aiolimiter<2.0.0,>=1.1.0 (from voyageai)
#   Downloading aiolimiter-1.2.1-py3-none-any.whl.metadata (4.5 kB)
# Collecting numpy>=1.11 (from voyageai)
#   Downloading numpy-2.4.4-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: requests<3.0,>=2.20 in .\.venv\Lib\site-packages (from voyageai) (2.33.1)
# Collecting tenacity>=8.0.1 (from voyageai)
#   Downloading tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0,>=3.5->voyageai)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0,>=3.5->voyageai)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in .\.venv\Lib\site-packages (from aiohttp<4.0,>=3.5->voyageai) (26.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0,>=3.5->voyageai)
#   Downloading frozenlist-1.8.0-cp314-cp314-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0,>=3.5->voyageai)
#   Downloading multidict-6.7.1-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0,>=3.5->voyageai)
#   Downloading propcache-0.4.1-cp314-cp314-win_amd64.whl.metadata (14 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0,>=3.5->voyageai)
#   Downloading yarl-1.23.0-cp314-cp314-win_amd64.whl.metadata (82 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.venv\Lib\site-packages (from requests<3.0,>=2.20->voyageai) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in .\.venv\Lib\site-packages (from requests<3.0,>=2.20->voyageai) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in .\.venv\Lib\site-packages (from requests<3.0,>=2.20->voyageai) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in .\.venv\Lib\site-packages (from requests<3.0,>=2.20->voyageai) (2026.2.25)
# Downloading voyageai-0.2.4-py3-none-any.whl (20 kB)
# Downloading aiohttp-3.13.5-cp314-cp314-win_amd64.whl (464 kB)
# Downloading aiolimiter-1.2.1-py3-none-any.whl (6.7 kB)
# Downloading multidict-6.7.1-cp314-cp314-win_amd64.whl (45 kB)
# Downloading yarl-1.23.0-cp314-cp314-win_amd64.whl (89 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.8.0-cp314-cp314-win_amd64.whl (44 kB)
# Downloading numpy-2.4.4-cp314-cp314-win_amd64.whl (12.4 MB)
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ------- -------------------------------- 2.4/12.4 MB 12.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.0/12.4 MB 12.9 MB/s eta 0:00:01
#    -------------------------- ------------- 8.1/12.4 MB 13.3 MB/s eta 0:00:01
#    --------------------------------- ------ 10.5/12.4 MB 13.2 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 12.5 MB/s  0:00:01
# Downloading propcache-0.4.1-cp314-cp314-win_amd64.whl (41 kB)
# Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Installing collected packages: tenacity, propcache, numpy, multidict, frozenlist, aiolimiter, aiohappyeyeballs, yarl, aiosignal, aiohttp, voyageai
#
#    --- ------------------------------------  1/11 [propcache]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    ------- --------------------------------  2/11 [numpy]
#    -------------- -------------------------  4/11 [frozenlist]
#    ------------------------- --------------  7/11 [yarl]
#    -------------------------------- -------  9/11 [aiohttp]
#    -------------------------------- -------  9/11 [aiohttp]
#    -------------------------------- -------  9/11 [aiohttp]
#    ------------------------------------ --- 10/11 [voyageai]
#    ---------------------------------------- 11/11 [voyageai]
#
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.5 aiolimiter-1.2.1 aiosignal-1.4.0 frozenlist-1.8.0 multidict-6.7.1 numpy-2.4.4 propcache-0.4.1 tenacity-9.1.4 voyageai-0.2.4 yarl-1.23.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Client Setup
from dotenv import load_dotenv
import voyageai

load_dotenv()

client = voyageai.Client()

# %%
# Chunk by section
import re


def chunk_by_section(document_text):
    pattern = r"\n## "
    return re.split(pattern, document_text)

# %%
# Embedding Generation
def generate_embedding(text, model="voyage-3-large", input_type="query"):
    result = client.embed([text], model=model, input_type=input_type)

    return result.embeddings[0]

# %%
with open("./report.md", "r") as f:
    text = f.read()

chunks = chunk_by_section(text)

generate_embedding(chunks[0])
